# %%
import pickle
import os
import pandas as pd
#from config import BASE_DIR
#print(os.getcwd())
#os.chdir(BASE_DIR)
#print(BASE_DIR)
#
#import scripts.OrderBookAnalizer as oba
#import scripts.functions as fn

# %% [markdown]
# ### Leer archivo de datos

# %%
#symbol='BTCUSDT'
#LOG_DIR = os.path.join(BASE_DIR,'log')
#DATA_FILE = os.path.join(LOG_DIR, f"order_book_{symbol}.pkl")
DATA_FILE = '../../orderbook_data/cumulative_snapshots.pkl'
if os.path.exists(DATA_FILE):
    with open(DATA_FILE, "rb") as archivo:
        df = pickle.load(archivo)
df
# Out:
#                       TimestampUTC   Symbol   LastUpdateID  TotalBidVolume  \
# 0 2025-04-20 15:12:13.917826+00:00  BTCUSDT  7314390290463      2414.84500
# 1 2025-04-20 15:17:04.190028+00:00  BTCUSDT  7314411385421      3166.85700
# 2 2025-04-20 15:23:49.980131+00:00  BTCUSDT  7314442315581      2009.94000
# 3 2025-04-20 15:47:14.111231+00:00  BTCUSDT  7314542912256      1790.06800
# 4 2025-04-20 15:47:57.243761+00:00  BTCUSDT    67173527713       511.59604
# 5 2025-04-21 00:07:05.419268+00:00  BTCUSDT    67197494015      2045.96652
# 6 2025-04-21 00:11:16.030020+00:00  BTCUSDT  7316627503539      3023.13400
# 7 2025-04-21 00:12:19.336091+00:00  BTCUSDT    67197764837       490.11952
#
#    TotalAskVolume  BestBidPrice  BestAskPrice   MidPrice  \
# 0     1603.918000      84453.00      84453.10  84453.050
# 1     2171.117000      84411.60      84411.70  84411.650
# 2     1437.271000      84401.60      84401.70  84401.650
# 3     1765.291000      84442.40      84442.50  84442.450
# 4      305.096050      84457.99      84458.00  84457.995
# 5      818.857640      85310.46      85310.47  85310.465
# 6     3535.399000      85299.20      85299.30  85299.250
# 7      270.940376      85319.03      85319.04  85319.035
#
#                                       Top20BidsByVol  \
# 0  [[81000.0, 692.825], [1000.0, 207.648], [80865...
# 1                                                NaN
# 2  [[83750.0, 365.181], [1000.0, 207.648], [83500...
# 3  [[83800.0, 282.684], [1000.0, 207.648], [83500...
# 4  [[83000.0, 90.33525], [60000.0, 82.91936], [83...
# 5  [[80000.0, 216.05911], [75000.0, 206.66047], [...
# 6  [[81000.0, 702.326], [83800.0, 263.291], [1000...
# 7  [[75000.0, 206.66627], [60000.0, 82.93035], [4...
#
#                                       Top20AsksByVol  NumBidLevels  \
# 0  [[86000.0, 134.494], [85000.0, 41.032], [85800...          2101
# 1                                                NaN          2131
# 2  [[86500.0, 111.498], [84501.6, 104.177], [8454...          1521
# 3  [[85500.0, 385.818], [86000.0, 134.057], [8700...          1466
# 4  [[85500.0, 35.74836], [87500.0, 26.98922], [84...          1079
# 5  [[95000.0, 163.16791], [90000.0, 99.60338], [9...          1409
# 6  [[85555.0, 475.834], [85500.0, 471.474], [8545...          2170
# 7  [[85500.0, 42.75526], [86480.0, 20.06968], [85...          1262
#
#    NumAskLevels  APIBestBid  APIBestAsk  APIMidPrice  \
# 0          2214     84453.0     84453.1     84453.05
# 1          2171     84411.6     84411.7     84411.65
# 2          1570     84401.6     84401.7     84401.65
# 3          1329     84442.4     84442.5     84442.45
# 4          1086     84424.0     84424.1     84424.05
# 5          1031         NaN         NaN          NaN
# 6          2324     85293.7     85293.8     85293.75
# 7          1025     85277.7     85277.8     85277.75
#
#                                       Top10BidsByVol  \
# 0                                                NaN
# 1  [[81000.0, 692.9], [83750.0, 366.154], [1000.0...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#                                       Top10AsksByVol
# 0                                                NaN
# 1  [[85500.0, 385.156], [86000.0, 134.532], [8650...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
